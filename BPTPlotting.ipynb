# %%
import matplotlib.pyplot as plt 
import matplotlib.image as mpimg 
import os

# %%
os.chdir('C:/Downloads')

# %%
## Finding the folder

import os
import subprocess

folder_path = os.path.abspath("bpt_plots")
subprocess.Popen(f'explorer "{folder_path}"')
# Out:
# <Popen: returncode: None args: 'explorer "c:\\GitHub Repository\\AGN-Classif...>

# %%
img_path = os.path.join("bpt_plots", "jades", "jades_z_5.0_to_5.8.png")
img = mpimg.imread(img_path)
plt.imshow(img)
plt.axis('off')
plt.title('BPT Plot: JADES z = 5-5.8')
plt.show()
